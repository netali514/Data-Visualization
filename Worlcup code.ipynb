# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

from scipy import stats
from scipy.stats import norm, skew

import seaborn as sns
color = sns.color_palette()
sns.set_style('darkgrid')

import warnings
warnings.filterwarnings('ignore')

import os
print(os.listdir("."))
# Out:
# ['.anaconda', '.conda', '.condarc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.nuget', '.QtWebEngineProcess', '.spyder-py3', '.Tableau Public', '3D Objects', 'Anaconda3', 'AppData', 'Application Data', 'Contacts', 'Cookies', 'Desktop', 'Documents', 'Downloads', 'Favorites', 'IntelGraphicsProfiles', 'knime-workspace', 'Links', 'Local Settings', 'MicrosoftEdgeBackups', 'Music', 'My Documents', 'NetHood', 'Newdata.csv', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{7ba7cd8a-51f1-11e9-aa84-c3bcac5b08bc}.TM.blf', 'NTUSER.DAT{7ba7cd8a-51f1-11e9-aa84-c3bcac5b08bc}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{7ba7cd8a-51f1-11e9-aa84-c3bcac5b08bc}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'Pictures', 'Players.csv', 'PrintHood', 'Recent', 'Saved Games', 'ScStore', 'Searches', 'SendTo', 'Start Menu', 'Superstore new.twbx', 'Templates', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb', 'Untitled3.ipynb', 'Vide
# ...

# %%
wc = pd.read_csv('Players.csv')

# %%
wc.head()
# Out:
#      Player Name      Country  Captain         Role  CareerBattingAverage  \
# 0     Aftab Alam  Afghanistan      0.0  All0rounder                 12.20
# 1  Asghar Afghan  Afghanistan      0.0      Batsman                 23.94
# 2  Dawlat Zadran  Afghanistan      0.0       Bowler                 20.91
# 3  Gulbadin Naib  Afghanistan      1.0  All0rounder                 22.41
# 4   Hamid Hassan  Afghanistan      0.0       Bowler                  7.07
#
#    Career_Batting_StrikeRate  HardHitting  Finisher  Consistency  \
# 0                      69.31     0.431818  0.111111    12.200000
# 1                      64.85     0.272785  0.037500    23.941176
# 2                      80.06     0.443381  0.500000    20.916667
# 3                      71.03     0.329225  0.160000    22.416667
# 4                      53.80     0.280702  0.021739     7.076923
#
#    RunningBetweekWkts Career_Bowling_Average  Career_Bowling_Economy  \
# ...

# %%
cormat = wc1.corr()
f, ax= plt.subplots(figsize=(20,15))
sns.heatmap(cormat, annot=True, linewidths=.5, fmt= '.1f',ax=ax)

# %%
wc1 = wc[wc.columns[4:]]
wc1 = wc1.rename(columns={'Career_Batting_strikeRate': 'StrikeRate'})

# %%
wc1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 14 columns):
# CareerBattingAverage                 150 non-null float64
# Career_Batting_StrikeRate            150 non-null float64
# HardHitting                          150 non-null float64
# Finisher                             150 non-null float64
# Consistency                          150 non-null float64
# RunningBetweekWkts                   150 non-null float64
# Career_Bowling_Average               150 non-null object
# Career_Bowling_Economy               150 non-null float64
# Career_Bowling_StrikeRate            150 non-null float64
# WktTakingAbility                     150 non-null float64
# CrucialWktTakingAbility              150 non-null float64
# ShortPerfIndex                       150 non-null float64
# CaptainWinLossRatio                  150 non-null float64
# Career_Fielding_DismissalsPerInns    150 non-null float64
# dtypes: float64(13), object(1)
# ...

# %%
    sns.set()
    cols = ['CareerBattingAverage', 'Career_Batting_StrikeRate', 'Hardhitting','Finisher', 'Consistency', 'RunningBetweekWkts']
    plt.figure()
    g=sns.pairplot(wc1.columns, size = 2)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-7384934651d0> in <module>
#       2 cols = ['CareerBattingAverage', 'Career_Batting_StrikeRate', 'Hardhitting','Finisher', 'Consistency', 'RunningBetweekWkts']
#       3 plt.figure()
# ----> 4 g=sns.pairplot(wc1.columns, size = 2)
#       5 plt.show()
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2068         raise TypeError(
#    2069             "'data' must be pandas DataFrame object, not: {typefound}".format(
# -> 2070                 typefound=type(data)))
#    2071
#    2072     if plot_kws is None:
#
# TypeError: 'data' must be pandas DataFrame object, not: <class 'pandas.core.indexes.base.Index'>
